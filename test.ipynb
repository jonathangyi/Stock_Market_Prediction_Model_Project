# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")
data = ticker.history(period="5d")
print(data)
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 import yfinance as yf
#       3 ticker = yf.Ticker("AAPL")
# ----> 4 data = ticker.history(period="5d")
#       5 print(data)
#
# File c:\Users\james\anaconda3\envs\myenv\lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\james\anaconda3\envs\myenv\lib\site-packages\yfinance\base.py:91, in TickerBase.history(self, *args, **kwargs)
#      89 @utils.log_indent_decorator
#      90 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 91     return self._lazy_load_price_history().history(*args, **kwargs)
#
# ...
